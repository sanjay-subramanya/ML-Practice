# %%
import pandas as pd
df = pd.read_csv(r'AAPL.csv')

# %% [markdown]
# # New Section

# %%
df.head()
# Out:
#    Unnamed: 0 symbol  ... divCash  splitFactor
# 0           0   AAPL  ...     0.0          1.0
# 1           1   AAPL  ...     0.0          1.0
# 2           2   AAPL  ...     0.0          1.0
# 3           3   AAPL  ...     0.0          1.0
# 4           4   AAPL  ...     0.0          1.0
#
# [5 rows x 15 columns]

# %%
df.tail()
# Out:
#       Unnamed: 0 symbol  ... divCash  splitFactor
# 1253        1253   AAPL  ...     0.0          1.0
# 1254        1254   AAPL  ...     0.0          1.0
# 1255        1255   AAPL  ...     0.0          1.0
# 1256        1256   AAPL  ...     0.0          1.0
# 1257        1257   AAPL  ...     0.0          1.0
#
# [5 rows x 15 columns]

# %%
df1 = df.reset_index()['close']
df1.head()
# Out:
# 0    132.045
# 1    131.780
# 2    130.280
# 3    130.535
# 4    129.960
# Name: close, dtype: float64

# %%
df1.shape
# Out:
# (1258,)

# %%
import matplotlib.pyplot as plt
plt.plot(df1)

# %%
# LSTM are sensitive to the scale of the data. so we apply MinMax scaler

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range = (0,1))
df1 = scaler.fit_transform(np.array(df1).reshape(-1, 1))

# %%
df1  # has been transformed into 1-D array
# Out:
# array([[0.17607447],
#        [0.17495567],
#        [0.16862282],
#        ...,
#        [0.96635143],
#        [0.9563033 ],
#        [0.96491598]])

# %%
#splitting dataset into train and test split
training_size = int(0.65*len(df1))
test_size = len(df1) - training_size

train_data, test_data = df1[0:training_size, :], df1[training_size:len(df1), :]

# %%
train_data.shape, test_data.shape
# Out:
# ((817, 1), (441, 1))

# %%
train_data
# Out:
# array([[0.17607447],
#        [0.17495567],
#        [0.16862282],
#        [0.1696994 ],
#        [0.16727181],
#        [0.16794731],
#        [0.16473866],
#        [0.16174111],
#        [0.1581525 ],
#        [0.15654817],
#        [0.16271215],
#        [0.1614878 ],
#        [0.1554927 ],
#        [0.15443722],
#        [0.15730811],
#        [0.15604154],
#        [0.15849025],
#        [0.15308621],
#        [0.15735033],
#        [0.15490163],
#        [0.15946129],
#        [0.15688592],
#        [0.1537195 ],
#        [0.14434687],
#        [0.14812547],
#        [0.15308621],
#        [0.15241071],
#        [0.15055307],
#        [0.14924428],
#        [0.13607194],
#        [0.12551718],
#        [0.13906949],
#        [0.14911762],
#        [0.14890653],
#        [0.15401503],
#        [0.16115005],
#        [0.16583636],
#        [0.17618002],
#        [0.17060711],
#        [0.14725998],
#        [0.14700667],
#        [0.14422021],
#        [0.13691632],
# ...

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step):
    dataX, dataY = [], []
    for i in range(len(dataset) - time_step - 1):
        a = dataset[i : i+time_step, 0]            #i=0, 0,1,2,3-----99   100 
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

# %%
# reshape into X=t,t+1,t+2,t+3 and Y=t+4
time_steps = 100
x_train, y_train = create_dataset(train_data, time_steps)
x_test, y_test = create_dataset(test_data, time_steps)

# %%
y_train.shape, x_train.shape
# Out:
# ((716,), (716, 100))

# %%
x_test.shape, y_test.shape
# Out:
# ((340, 100), (340,))

# %%
print(x_train)
# Out:
# [[0.17607447 0.17495567 0.16862282 ... 0.09055982 0.08388922 0.09085536]
#  [0.17495567 0.16862282 0.1696994  ... 0.08388922 0.09085536 0.0873934 ]
#  [0.16862282 0.1696994  0.16727181 ... 0.09085536 0.0873934  0.09030651]
#  ...
#  [0.34801148 0.32930845 0.32145571 ... 0.50042219 0.50413747 0.5062062 ]
#  [0.32930845 0.32145571 0.32694419 ... 0.50413747 0.5062062  0.51920966]
#  [0.32145571 0.32694419 0.32230009 ... 0.5062062  0.51920966 0.53719497]]

# %%
# reshape input to be [samples, time steps, features] which is required for LSTM
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], 1)
x_test = x_test.reshape(x_test.shape[0], x_test.shape[1], 1)

x_train.shape
# Out:
# (716, 100, 1)

# %%
### Create the Stacked LSTM model
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense

#physical_devices = tf.config.list_physical_devices("GPU")
#tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
model = Sequential([LSTM(50, return_sequences = True, input_shape = (100, 1)),
                    LSTM(50, return_sequences = True), 
                    LSTM(50),
                    Dense(1)])

model.compile(optimizer = 'adam', loss = 'mean_squared_error')

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm (LSTM)                  (None, 100, 50)           10400
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100, 50)           20200
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 51
# ...
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train, y_train, validation_data = (x_test, y_test), epochs = 80, batch_size = 64, verbose =1)
# Out:
# Epoch 1/80
# 12/12 [==============================] - 1s 86ms/step - loss: 4.1495e-04 - val_loss: 0.0025
# Epoch 2/80
# 12/12 [==============================] - 1s 82ms/step - loss: 3.4170e-04 - val_loss: 0.0015
# Epoch 3/80
# 12/12 [==============================] - 1s 82ms/step - loss: 3.5091e-04 - val_loss: 0.0015
# Epoch 4/80
# 12/12 [==============================] - 1s 82ms/step - loss: 3.2181e-04 - val_loss: 0.0016
# Epoch 5/80
# 12/12 [==============================] - 1s 81ms/step - loss: 3.1126e-04 - val_loss: 0.0015
# Epoch 6/80
# 12/12 [==============================] - 1s 80ms/step - loss: 3.0595e-04 - val_loss: 0.0014
# Epoch 7/80
# 12/12 [==============================] - 1s 80ms/step - loss: 3.0383e-04 - val_loss: 0.0014
# Epoch 8/80
# 12/12 [==============================] - 1s 82ms/step - loss: 2.9222e-04 - val_loss: 0.0014
# Epoch 9/80
# 12/12 [==============================] - 1s 83ms/step - loss: 3.2492e-04 - val_loss: 0.0020
# Epoch 10/80
# ...

# %%
# Lets Do the prediction and check performance metrics
train_predict = model.predict(x_train)
test_predict = model.predict(x_test)

# %%
#Transform back to original form
train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)

# %%
# Calculate RMSE performance metrics
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(y_train, train_predict))
# Out:
# 142.18834826739123

# %%
math.sqrt(mean_squared_error(y_test, test_predict))
# Out:
# 236.82920215691416

# %%
# Plotting 
# shift train predictions for plotting
look_back = 100
trainPredictPlot = np.empty_like(df1)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict) + look_back, :] = train_predict

# shift test predictions for plotting
testPredictPlot = np.empty_like(df1)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(train_predict) + (look_back*2) + 1 : len(df1) - 1, :] = test_predict

# plot baseline and prediction
plt.plot(scaler.inverse_transform(df1))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
len(test_data)
# Out:
# 441

# %%
# Predict next 30 days
# We need previous 100 days' data, 441 - 100 = 341

x_data = test_data[341:, :].reshape(1, -1)
x_data.shape
# Out:
# (1, 100)

# %%
temp_input = list(x_data)
temp_input = temp_input[0].tolist()

temp_input
# Out:
# [0.8583551465000423,
#  0.8866418981676942,
#  0.8743139407244789,
#  0.8843198513890065,
#  0.8783669678290975,
#  0.8986321033521913,
#  0.925821160179009,
#  0.9287764924427933,
#  0.9567677108840666,
#  0.9386979650426415,
#  0.933040614709111,
#  0.9495060373216249,
#  0.9642404796082076,
#  0.9551211686228154,
#  0.9598919192772104,
#  0.9663514312251966,
#  0.9624672802499368,
#  0.9229502659799038,
#  0.9598497002448705,
#  0.9879253567508233,
#  0.985941062230854,
#  0.9253145317909315,
#  0.9217259140420504,
#  0.964747107996285,
#  0.9757240564046274,
#  0.9915984125643842,
#  0.9697289538123788,
#  0.9761462467280253,
#  0.9679557544541082,
#  1.0000000000000002,
#  0.9901629654648318,
#  0.9905007177235499,
#  0.9653803934813816,
#  0.9848855864223593,
#  0.9708688676855528,
#  0.9402600692392133,
#  0.8774803681499621,
#  0.8348391454867856,
#  0.8541332432660644,
#  0.7733682344000676,
#  0.7726927298826314,
#  0.8801401671873683,
#  0.8400743054969182,
# ...

# %%
# demonstrate prediction for next 30 days
from numpy import array
last_output = []
i = 0
n_steps = 100
while(i<30):

  if(len(temp_input) > 100):

    #print(temp_input)
    x_data = np.array(temp_input[1:])
    print('{} day input {}'.format(i, x_data))
    x_data = x_data.reshape(1, -1)
    x_data = x_data.reshape(1, n_steps, 1)
    #print(x_input)
    yhat = model.predict(x_data, verbose = 0)
    print("{} day output {}".format(i, yhat))
    temp_input.extend(yhat[0].tolist())
    temp_input = temp_input[1:]
    #print(temp_input)
    last_output.extend(yhat.tolist())
    i+=1

  else:
    x_data = x_data.reshape(1, n_steps, 1)
    yhat = model.predict(x_data, verbose = 0)
    print(yhat[0])
    temp_input.extend(yhat[0].tolist())
    print(len(temp_input))
    last_output.extend(yhat.tolist())
    i+=1

print(last_output)
# Out:
# [0.94230264]
# 101
# 1 day input [0.8866419  0.87431394 0.88431985 0.87836697 0.8986321  0.92582116
#  0.92877649 0.95676771 0.93869797 0.93304061 0.94950604 0.96424048
#  0.95512117 0.95989192 0.96635143 0.96246728 0.92295027 0.9598497
#  0.98792536 0.98594106 0.92531453 0.92172591 0.96474711 0.97572406
#  0.99159841 0.96972895 0.97614625 0.96795575 1.         0.99016297
#  0.99050072 0.96538039 0.98488559 0.97086887 0.94026007 0.87748037
#  0.83483915 0.85413324 0.77336823 0.77269273 0.88014017 0.84007431
#  0.89673225 0.85527316 0.83884995 0.74233725 0.82327113 0.78143207
#  0.6665963  0.7921557  0.64118044 0.68614371 0.66001013 0.65203074
#  0.58642236 0.56586169 0.66089673 0.65515494 0.70970193 0.66452757
#  0.69437642 0.69218104 0.63569197 0.65266402 0.63780292 0.7267162
#  0.71388162 0.74191506 0.75002111 0.77222832 0.83049059 0.8194292
#  0.8289707  0.8125475  0.78776492 0.75162543 0.78426074 0.77974331
#  0.81326522 0.8141096  0.79473106 0.83336148 0.85898843 0.83901883
# ...

# %%
day_new = np.arange(1, 101)
day_pred = np.arange(101, 131)

# %%
len(df1)
# Out:
# 1258

# %%
plt.plot(day_new, scaler.inverse_transform(df1[1158:]))
plt.plot(day_pred, scaler.inverse_transform(last_output))

# %%
df3 = df1.tolist()
df3.extend(last_output)
plt.plot(df3[1200:])

# %%
df3 = scaler.inverse_transform(df3).tolist()

# %%
plt.plot(df3)
